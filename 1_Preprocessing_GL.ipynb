# %% [markdown]
# <a href="https://colab.research.google.com/github/gylam/siads696-sprsum2024-team05/blob/main/1_Preprocessing_GL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Document retrieval**
# <br>
# Goal: Retrieve all English non-text documents containing themes - output table with document text and associated theme labels

# %%
import requests
import pandas as pd
from functools import reduce
import typing
import time

## URLs for API calls
# Uses profile for API calls, excludes images/URLs, includes all following filters
url_base = "https://api.reliefweb.int/v1/reports?appname=rwint-user-0&profile=list&slim=1&filter[operator]=AND"
# Sort by ascending document ID
url_sort = "&sort[]=id:asc"
# Filter for English language reports
url_lang = "&filter[conditions][0][field]=language.id&filter[conditions][0][value]=267"
# Exclude non-text formats (Infographic, Interactive, Map, Other)
url_format1 = "&filter[conditions][1][field]=format.id&filter[conditions][1][value][]=12570&filter[conditions][1][value][]=12"
url_format2 = "&filter[conditions][1][value][]=9&filter[conditions][1][value][]=38974&filter[conditions][1][operator]=OR&filter[conditions][1][negate]=true"
# Filter for documents tagged with format, source, and at least 1 theme
url_theme_filt = "&filter[conditions][2][field]=theme&filter[conditions][3][field]=format&filter[conditions][4][field]=source"
# Filter for documents with Climate Change theme - for unsupervised learning
url_theme_climate = "&filter[conditions][5][field]=theme.id&filter[conditions][5][value]=4588"
# Return fields from document - body, theme, format, primary country, document ID
url_fields = "&fields[include][]=body&fields[include][]=theme&fields[include][]=format&fields[include][]=primary_country&fields[include][]=id"

def extract_docs(doc_limit: int = 1000, tot_docs: int = None) -> pd.DataFrame:
  """ Call API to extract all English-language text documents with themes
      Inputs:
        - doc_limit: Number of documents to retrieve at a time (default and max is 1000)
        - tot_docs: Total number of documents to retrieve (default is to retrieve all matching results)
      Output:
        - doc_df: Dataframe containing document text and themes
  """
  print(f"Initial args: doc_limit = {doc_limit}, tot_docs = {tot_docs}")
  # Set counter to track number of iterations until reach last set of documents
  counter = 0
  doc_df_created = False

  # If no limit to tot_docs is specified, initially set to doc_limit
  if tot_docs == None:
    tot_docs = doc_limit
    tot_docs_bool = False
  else:
    tot_docs_bool = True

  # URL to indicate number of documents to return and how many to offset by
  url_lim = f"&limit={doc_limit}&offset="

  # Call API until all documents have been retrieved
  while counter*doc_limit <= tot_docs:
    print(f"counter = {counter} with {counter*doc_limit} documents elapsed")
#    print(f"tot_docs: {tot_docs}")
    # Make API request
    full_url = url_base + url_sort + url_lang + url_format1 + url_format2 + \
                 url_theme_filt + url_fields + url_lim + str(counter*doc_limit)
#    print(f"full_url: {full_url}")
    response = requests.get(full_url, stream = True)

    # Check that valid API call was made
    if response.status_code == 200:
      # If so, convert JSON output into dictionary
      try:
        data = response.json()
      except Exception as e:
        print(f"Error {e}")
        time.sleep(2)
        continue

      # Generate dataframes for each list of dictionaries and merge on document ID
      df_all = pd.json_normalize(data["data"])
      df_theme = pd.json_normalize(data["data"],
                                  record_path = ["fields", "theme"],
                                  meta = [["fields", "id"], ["fields", "title"],
                                          ["fields", "body"],
                                          ["fields", "primary_country", "name"],
                                          ["fields", "primary_country", "location", "lat"],
                                          ["fields", "primary_country", "location", "lon"],
                                          ["fields", "date", "created"]],
                                  record_prefix = "theme.",
                                  errors = "ignore"
                                  ).astype("str")
      df_country = pd.json_normalize(data["data"],
                                      record_path = ["fields", "country"],
                                      meta = ["fields", "id"],
                                      meta_prefix = "fields.",
                                      record_prefix = "country.")
      df_source = pd.json_normalize(data["data"],
                                      record_path = ["fields", "source"],
                                      meta = ["fields", "id"],
                                      meta_prefix = "fields.",
                                      record_prefix = "source.")
      df_format = pd.json_normalize(data["data"],
                                      record_path = ["fields", "format"],
                                      meta = ["fields", "id"],
                                      meta_prefix = "fields.",
                                      record_prefix = "format.")
      df_to_merge = [df_theme, #df_country[["country.name", "fields.id"]],
                      df_source[["source.name", "fields.id"]],
                      df_format[["format.name", "fields.id"]]]
      merged_df_curr = reduce(lambda left, right: \
                                  pd.merge(left, right, on = ["fields.id"],
                                           how = "left"), df_to_merge)

      # For first call, create dataframe and update total number of documents if no total specified
      if doc_df_created == False:
        doc_df = merged_df_curr
#        df_all_total = df_all
        if tot_docs_bool == False:
          tot_docs = data["totalCount"]
        doc_df_created = True
      # Otherwise, concatenate to doc_df
      else:
        doc_df_num_docs_prev = len(doc_df['fields.id'].unique())
#        print(f"Doc IDs in doc_df already: {set(merged_df_curr['fields.id'])&set(doc_df['fields.id'])}")
        doc_df = pd.concat([doc_df, merged_df_curr])
        doc_df_num_docs_curr = len(doc_df['fields.id'].unique())
        print(f"Number of docs in df: {doc_df_num_docs_curr}, diff = {doc_df_num_docs_curr - doc_df_num_docs_prev}")

        # print(f"df_all # rows: {len(df_all)}")
        # df_all_total_prev = len(df_all_total)
        # df_all_total = pd.concat([df_all_total, df_all])
        # print(f"Number of docs in df_all_total: {len(df_all_total)}, diff = {len(df_all_total) - df_all_total_prev}")
    counter += 1
    print("\n")
  return doc_df

# %%
#output = extract_docs(4, 8)
output = extract_docs()
print(f"output.shape: {output.shape}")
output.head()
# Out:
# Initial args: doc_limit = 1000, tot_docs = None
# counter = 0 with 0 documents elapsed
#
#
# counter = 1 with 1000 documents elapsed
# Number of docs in df: 2000, diff = 1000
#
#
# counter = 2 with 2000 documents elapsed
# Number of docs in df: 3000, diff = 1000
#
#
# counter = 3 with 3000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 3 with 3000 documents elapsed
# Number of docs in df: 4000, diff = 1000
#
#
# counter = 4 with 4000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 4 with 4000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 4 with 4000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 4 with 4000 documents elapsed
# Number of docs in df: 5000, diff = 1000
#
#
# counter = 5 with 5000 documents elapsed
# Number of docs in df: 6000, diff = 1000
#
#
# counter = 6 with 6000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 6 with 6000 documents elapsed
# Number of docs in df: 7000, diff = 1000
#
#
# counter = 7 with 7000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 7 with 7000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 7 with 7000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 7 with 7000 documents elapsed
# Number of docs in df: 8000, diff = 1000
#
#
# counter = 8 with 8000 documents elapsed
# Number of docs in df: 9000, diff = 1000
#
#
# counter = 9 with 9000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 9 with 9000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 9 with 9000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 9 with 9000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 9 with 9000 documents elapsed
# Number of docs in df: 10000, diff = 1000
#
#
# counter = 10 with 10000 documents elapsed
# Number of docs in df: 11000, diff = 1000
#
#
# counter = 11 with 11000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 11 with 11000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 11 with 11000 documents elapsed
# Number of docs in df: 12000, diff = 1000
#
#
# counter = 12 with 12000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 12 with 12000 documents elapsed
# Number of docs in df: 13000, diff = 1000
#
#
# counter = 13 with 13000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 13 with 13000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 13 with 13000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 13 with 13000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 13 with 13000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 13 with 13000 documents elapsed
# Number of docs in df: 14000, diff = 1000
#
#
# counter = 14 with 14000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 14 with 14000 documents elapsed
# Number of docs in df: 15000, diff = 1000
#
#
# counter = 15 with 15000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 15 with 15000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 15 with 15000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 15 with 15000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 15 with 15000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 15 with 15000 documents elapsed
# Number of docs in df: 16000, diff = 1000
#
#
# counter = 16 with 16000 documents elapsed
# Number of docs in df: 17000, diff = 1000
#
#
# counter = 17 with 17000 documents elapsed
# Number of docs in df: 18000, diff = 1000
#
#
# counter = 18 with 18000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 18 with 18000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 18 with 18000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 18 with 18000 documents elapsed
# Number of docs in df: 19000, diff = 1000
#
#
# counter = 19 with 19000 documents elapsed
# Number of docs in df: 20000, diff = 1000
#
#
# counter = 20 with 20000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 20 with 20000 documents elapsed
# Number of docs in df: 21000, diff = 1000
#
#
# counter = 21 with 21000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 21 with 21000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 21 with 21000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 21 with 21000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 21 with 21000 documents elapsed
# Number of docs in df: 22000, diff = 1000
#
#
# counter = 22 with 22000 documents elapsed
# Number of docs in df: 23000, diff = 1000
#
#
# counter = 23 with 23000 documents elapsed
# Number of docs in df: 24000, diff = 1000
#
#
# counter = 24 with 24000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 24 with 24000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 24 with 24000 documents elapsed
# Number of docs in df: 25000, diff = 1000
#
#
# counter = 25 with 25000 documents elapsed
# Number of docs in df: 26000, diff = 1000
#
#
# counter = 26 with 26000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 26 with 26000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 26 with 26000 documents elapsed
# Number of docs in df: 27000, diff = 1000
#
#
# counter = 27 with 27000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 27 with 27000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 27 with 27000 documents elapsed
# Number of docs in df: 28000, diff = 1000
#
#
# counter = 28 with 28000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 28 with 28000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 28 with 28000 documents elapsed
# Number of docs in df: 29000, diff = 1000
#
#
# counter = 29 with 29000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 29 with 29000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 29 with 29000 documents elapsed
# Number of docs in df: 30000, diff = 1000
#
#
# counter = 30 with 30000 documents elapsed
# Number of docs in df: 31000, diff = 1000
#
#
# counter = 31 with 31000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 31 with 31000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 31 with 31000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 31 with 31000 documents elapsed
# Number of docs in df: 32000, diff = 1000
#
#
# counter = 32 with 32000 documents elapsed
# Number of docs in df: 33000, diff = 1000
#
#
# counter = 33 with 33000 documents elapsed
# Number of docs in df: 34000, diff = 1000
#
#
# counter = 34 with 34000 documents elapsed
# Number of docs in df: 35000, diff = 1000
#
#
# counter = 35 with 35000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 35 with 35000 documents elapsed
# Number of docs in df: 36000, diff = 1000
#
#
# counter = 36 with 36000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 36 with 36000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 36 with 36000 documents elapsed
# Number of docs in df: 37000, diff = 1000
#
#
# counter = 37 with 37000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 37 with 37000 documents elapsed
# Number of docs in df: 38000, diff = 1000
#
#
# counter = 38 with 38000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 38 with 38000 documents elapsed
# Number of docs in df: 39000, diff = 1000
#
#
# counter = 39 with 39000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 39 with 39000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 39 with 39000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 39 with 39000 documents elapsed
# Number of docs in df: 40000, diff = 1000
#
#
# counter = 40 with 40000 documents elapsed
# Number of docs in df: 41000, diff = 1000
#
#
# counter = 41 with 41000 documents elapsed
# Number of docs in df: 42000, diff = 1000
#
#
# counter = 42 with 42000 documents elapsed
# Number of docs in df: 43000, diff = 1000
#
#
# counter = 43 with 43000 documents elapsed
# Number of docs in df: 44000, diff = 1000
#
#
# counter = 44 with 44000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 44 with 44000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 44 with 44000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 44 with 44000 documents elapsed
# Number of docs in df: 45000, diff = 1000
#
#
# counter = 45 with 45000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 45 with 45000 documents elapsed
# Number of docs in df: 46000, diff = 1000
#
#
# counter = 46 with 46000 documents elapsed
# Number of docs in df: 47000, diff = 1000
#
#
# counter = 47 with 47000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 47 with 47000 documents elapsed
# Number of docs in df: 48000, diff = 1000
#
#
# counter = 48 with 48000 documents elapsed
# Number of docs in df: 49000, diff = 1000
#
#
# counter = 49 with 49000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 49 with 49000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 49 with 49000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 49 with 49000 documents elapsed
# Number of docs in df: 50000, diff = 1000
#
#
# counter = 50 with 50000 documents elapsed
# Number of docs in df: 51000, diff = 1000
#
#
# counter = 51 with 51000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 51 with 51000 documents elapsed
# Number of docs in df: 52000, diff = 1000
#
#
# counter = 52 with 52000 documents elapsed
# Number of docs in df: 53000, diff = 1000
#
#
# counter = 53 with 53000 documents elapsed
# Number of docs in df: 54000, diff = 1000
#
#
# counter = 54 with 54000 documents elapsed
# Number of docs in df: 55000, diff = 1000
#
#
# counter = 55 with 55000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 55 with 55000 documents elapsed
# Number of docs in df: 56000, diff = 1000
#
#
# counter = 56 with 56000 documents elapsed
# Number of docs in df: 57000, diff = 1000
#
#
# counter = 57 with 57000 documents elapsed
# Number of docs in df: 58000, diff = 1000
#
#
# counter = 58 with 58000 documents elapsed
# Number of docs in df: 59000, diff = 1000
#
#
# counter = 59 with 59000 documents elapsed
# Number of docs in df: 60000, diff = 1000
#
#
# counter = 60 with 60000 documents elapsed
# Number of docs in df: 61000, diff = 1000
#
#
# counter = 61 with 61000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 61 with 61000 documents elapsed
# Number of docs in df: 62000, diff = 1000
#
#
# counter = 62 with 62000 documents elapsed
# Number of docs in df: 63000, diff = 1000
#
#
# counter = 63 with 63000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 63 with 63000 documents elapsed
# Number of docs in df: 64000, diff = 1000
#
#
# counter = 64 with 64000 documents elapsed
# Number of docs in df: 65000, diff = 1000
#
#
# counter = 65 with 65000 documents elapsed
# Number of docs in df: 66000, diff = 1000
#
#
# counter = 66 with 66000 documents elapsed
# Number of docs in df: 67000, diff = 1000
#
#
# counter = 67 with 67000 documents elapsed
# Number of docs in df: 68000, diff = 1000
#
#
# counter = 68 with 68000 documents elapsed
# Number of docs in df: 69000, diff = 1000
#
#
# counter = 69 with 69000 documents elapsed
# Number of docs in df: 70000, diff = 1000
#
#
# counter = 70 with 70000 documents elapsed
# Number of docs in df: 71000, diff = 1000
#
#
# counter = 71 with 71000 documents elapsed
# Number of docs in df: 72000, diff = 1000
#
#
# counter = 72 with 72000 documents elapsed
# Number of docs in df: 73000, diff = 1000
#
#
# counter = 73 with 73000 documents elapsed
# Number of docs in df: 74000, diff = 1000
#
#
# counter = 74 with 74000 documents elapsed
# Number of docs in df: 75000, diff = 1000
#
#
# counter = 75 with 75000 documents elapsed
# Number of docs in df: 76000, diff = 1000
#
#
# counter = 76 with 76000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 76 with 76000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 76 with 76000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 76 with 76000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 76 with 76000 documents elapsed
# Number of docs in df: 77000, diff = 1000
#
#
# counter = 77 with 77000 documents elapsed
# Number of docs in df: 78000, diff = 1000
#
#
# counter = 78 with 78000 documents elapsed
# Number of docs in df: 79000, diff = 1000
#
#
# counter = 79 with 79000 documents elapsed
# Number of docs in df: 80000, diff = 1000
#
#
# counter = 80 with 80000 documents elapsed
# Number of docs in df: 81000, diff = 1000
#
#
# counter = 81 with 81000 documents elapsed
# Number of docs in df: 82000, diff = 1000
#
#
# counter = 82 with 82000 documents elapsed
# Number of docs in df: 83000, diff = 1000
#
#
# counter = 83 with 83000 documents elapsed
# Number of docs in df: 84000, diff = 1000
#
#
# counter = 84 with 84000 documents elapsed
# Number of docs in df: 85000, diff = 1000
#
#
# counter = 85 with 85000 documents elapsed
# Number of docs in df: 86000, diff = 1000
#
#
# counter = 86 with 86000 documents elapsed
# Number of docs in df: 87000, diff = 1000
#
#
# counter = 87 with 87000 documents elapsed
# Number of docs in df: 88000, diff = 1000
#
#
# counter = 88 with 88000 documents elapsed
# Number of docs in df: 89000, diff = 1000
#
#
# counter = 89 with 89000 documents elapsed
# Number of docs in df: 90000, diff = 1000
#
#
# counter = 90 with 90000 documents elapsed
# Number of docs in df: 91000, diff = 1000
#
#
# counter = 91 with 91000 documents elapsed
# Number of docs in df: 92000, diff = 1000
#
#
# counter = 92 with 92000 documents elapsed
# Number of docs in df: 93000, diff = 1000
#
#
# counter = 93 with 93000 documents elapsed
# Number of docs in df: 94000, diff = 1000
#
#
# counter = 94 with 94000 documents elapsed
# Number of docs in df: 95000, diff = 1000
#
#
# counter = 95 with 95000 documents elapsed
# Number of docs in df: 96000, diff = 1000
#
#
# counter = 96 with 96000 documents elapsed
# Number of docs in df: 97000, diff = 1000
#
#
# counter = 97 with 97000 documents elapsed
# Number of docs in df: 98000, diff = 1000
#
#
# counter = 98 with 98000 documents elapsed
# Number of docs in df: 99000, diff = 1000
#
#
# counter = 99 with 99000 documents elapsed
# Number of docs in df: 100000, diff = 1000
#
#
# counter = 100 with 100000 documents elapsed
# Number of docs in df: 101000, diff = 1000
#
#
# counter = 101 with 101000 documents elapsed
# Number of docs in df: 102000, diff = 1000
#
#
# counter = 102 with 102000 documents elapsed
# Number of docs in df: 103000, diff = 1000
#
#
# counter = 103 with 103000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 103 with 103000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 103 with 103000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 103 with 103000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 103 with 103000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 103 with 103000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 103 with 103000 documents elapsed
# Number of docs in df: 104000, diff = 1000
#
#
# counter = 104 with 104000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 104 with 104000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 104 with 104000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 104 with 104000 documents elapsed
# Number of docs in df: 105000, diff = 1000
#
#
# counter = 105 with 105000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 105 with 105000 documents elapsed
# Number of docs in df: 106000, diff = 1000
#
#
# counter = 106 with 106000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 106 with 106000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 106 with 106000 documents elapsed
# Number of docs in df: 107000, diff = 1000
#
#
# counter = 107 with 107000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 107 with 107000 documents elapsed
# Number of docs in df: 108000, diff = 1000
#
#
# counter = 108 with 108000 documents elapsed
# Number of docs in df: 109000, diff = 1000
#
#
# counter = 109 with 109000 documents elapsed
# Number of docs in df: 110000, diff = 1000
#
#
# counter = 110 with 110000 documents elapsed
# Number of docs in df: 111000, diff = 1000
#
#
# counter = 111 with 111000 documents elapsed
# Number of docs in df: 112000, diff = 1000
#
#
# counter = 112 with 112000 documents elapsed
# Number of docs in df: 113000, diff = 1000
#
#
# counter = 113 with 113000 documents elapsed
# Number of docs in df: 114000, diff = 1000
#
#
# counter = 114 with 114000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 114 with 114000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 114 with 114000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 114 with 114000 documents elapsed
# Number of docs in df: 115000, diff = 1000
#
#
# counter = 115 with 115000 documents elapsed
# Number of docs in df: 116000, diff = 1000
#
#
# counter = 116 with 116000 documents elapsed
# Number of docs in df: 117000, diff = 1000
#
#
# counter = 117 with 117000 documents elapsed
# Number of docs in df: 118000, diff = 1000
#
#
# counter = 118 with 118000 documents elapsed
# Number of docs in df: 119000, diff = 1000
#
#
# counter = 119 with 119000 documents elapsed
# Number of docs in df: 120000, diff = 1000
#
#
# counter = 120 with 120000 documents elapsed
# Number of docs in df: 121000, diff = 1000
#
#
# counter = 121 with 121000 documents elapsed
# Number of docs in df: 122000, diff = 1000
#
#
# counter = 122 with 122000 documents elapsed
# Number of docs in df: 123000, diff = 1000
#
#
# counter = 123 with 123000 documents elapsed
# Number of docs in df: 124000, diff = 1000
#
#
# counter = 124 with 124000 documents elapsed
# Number of docs in df: 125000, diff = 1000
#
#
# counter = 125 with 125000 documents elapsed
# Number of docs in df: 126000, diff = 1000
#
#
# counter = 126 with 126000 documents elapsed
# Number of docs in df: 127000, diff = 1000
#
#
# counter = 127 with 127000 documents elapsed
# Number of docs in df: 128000, diff = 1000
#
#
# counter = 128 with 128000 documents elapsed
# Number of docs in df: 129000, diff = 1000
#
#
# counter = 129 with 129000 documents elapsed
# Number of docs in df: 130000, diff = 1000
#
#
# counter = 130 with 130000 documents elapsed
# Number of docs in df: 131000, diff = 1000
#
#
# counter = 131 with 131000 documents elapsed
# Number of docs in df: 132000, diff = 1000
#
#
# counter = 132 with 132000 documents elapsed
# Number of docs in df: 133000, diff = 1000
#
#
# counter = 133 with 133000 documents elapsed
# Number of docs in df: 134000, diff = 1000
#
#
# counter = 134 with 134000 documents elapsed
# Number of docs in df: 135000, diff = 1000
#
#
# counter = 135 with 135000 documents elapsed
# Number of docs in df: 136000, diff = 1000
#
#
# counter = 136 with 136000 documents elapsed
# Number of docs in df: 137000, diff = 1000
#
#
# counter = 137 with 137000 documents elapsed
# Number of docs in df: 138000, diff = 1000
#
#
# counter = 138 with 138000 documents elapsed
# Number of docs in df: 139000, diff = 1000
#
#
# counter = 139 with 139000 documents elapsed
# Number of docs in df: 140000, diff = 1000
#
#
# counter = 140 with 140000 documents elapsed
# Number of docs in df: 141000, diff = 1000
#
#
# counter = 141 with 141000 documents elapsed
# Number of docs in df: 142000, diff = 1000
#
#
# counter = 142 with 142000 documents elapsed
# Number of docs in df: 143000, diff = 1000
#
#
# counter = 143 with 143000 documents elapsed
# Number of docs in df: 144000, diff = 1000
#
#
# counter = 144 with 144000 documents elapsed
# Number of docs in df: 145000, diff = 1000
#
#
# counter = 145 with 145000 documents elapsed
# Number of docs in df: 146000, diff = 1000
#
#
# counter = 146 with 146000 documents elapsed
# Number of docs in df: 147000, diff = 1000
#
#
# counter = 147 with 147000 documents elapsed
# Number of docs in df: 148000, diff = 1000
#
#
# counter = 148 with 148000 documents elapsed
# Number of docs in df: 149000, diff = 1000
#
#
# counter = 149 with 149000 documents elapsed
# Number of docs in df: 150000, diff = 1000
#
#
# counter = 150 with 150000 documents elapsed
# Number of docs in df: 151000, diff = 1000
#
#
# counter = 151 with 151000 documents elapsed
# Number of docs in df: 152000, diff = 1000
#
#
# counter = 152 with 152000 documents elapsed
# Number of docs in df: 153000, diff = 1000
#
#
# counter = 153 with 153000 documents elapsed
# Number of docs in df: 154000, diff = 1000
#
#
# counter = 154 with 154000 documents elapsed
# Number of docs in df: 155000, diff = 1000
#
#
# counter = 155 with 155000 documents elapsed
# Number of docs in df: 156000, diff = 1000
#
#
# counter = 156 with 156000 documents elapsed
# Number of docs in df: 157000, diff = 1000
#
#
# counter = 157 with 157000 documents elapsed
# Number of docs in df: 158000, diff = 1000
#
#
# counter = 158 with 158000 documents elapsed
# Number of docs in df: 159000, diff = 1000
#
#
# counter = 159 with 159000 documents elapsed
# Number of docs in df: 160000, diff = 1000
#
#
# counter = 160 with 160000 documents elapsed
# Number of docs in df: 161000, diff = 1000
#
#
# counter = 161 with 161000 documents elapsed
# Number of docs in df: 162000, diff = 1000
#
#
# counter = 162 with 162000 documents elapsed
# Number of docs in df: 163000, diff = 1000
#
#
# counter = 163 with 163000 documents elapsed
# Number of docs in df: 164000, diff = 1000
#
#
# counter = 164 with 164000 documents elapsed
# Number of docs in df: 165000, diff = 1000
#
#
# counter = 165 with 165000 documents elapsed
# Number of docs in df: 166000, diff = 1000
#
#
# counter = 166 with 166000 documents elapsed
# Number of docs in df: 167000, diff = 1000
#
#
# counter = 167 with 167000 documents elapsed
# Number of docs in df: 168000, diff = 1000
#
#
# counter = 168 with 168000 documents elapsed
# Number of docs in df: 169000, diff = 1000
#
#
# counter = 169 with 169000 documents elapsed
# Number of docs in df: 170000, diff = 1000
#
#
# counter = 170 with 170000 documents elapsed
# Number of docs in df: 171000, diff = 1000
#
#
# counter = 171 with 171000 documents elapsed
# Number of docs in df: 172000, diff = 1000
#
#
# counter = 172 with 172000 documents elapsed
# Number of docs in df: 173000, diff = 1000
#
#
# counter = 173 with 173000 documents elapsed
# Number of docs in df: 174000, diff = 1000
#
#
# counter = 174 with 174000 documents elapsed
# Number of docs in df: 175000, diff = 1000
#
#
# counter = 175 with 175000 documents elapsed
# Number of docs in df: 176000, diff = 1000
#
#
# counter = 176 with 176000 documents elapsed
# Number of docs in df: 177000, diff = 1000
#
#
# counter = 177 with 177000 documents elapsed
# Number of docs in df: 178000, diff = 1000
#
#
# counter = 178 with 178000 documents elapsed
# Number of docs in df: 179000, diff = 1000
#
#
# counter = 179 with 179000 documents elapsed
# Number of docs in df: 180000, diff = 1000
#
#
# counter = 180 with 180000 documents elapsed
# Number of docs in df: 181000, diff = 1000
#
#
# counter = 181 with 181000 documents elapsed
# Number of docs in df: 182000, diff = 1000
#
#
# counter = 182 with 182000 documents elapsed
# Number of docs in df: 183000, diff = 1000
#
#
# counter = 183 with 183000 documents elapsed
# Number of docs in df: 184000, diff = 1000
#
#
# counter = 184 with 184000 documents elapsed
# Number of docs in df: 185000, diff = 1000
#
#
# counter = 185 with 185000 documents elapsed
# Number of docs in df: 186000, diff = 1000
#
#
# counter = 186 with 186000 documents elapsed
# Number of docs in df: 187000, diff = 1000
#
#
# counter = 187 with 187000 documents elapsed
# Number of docs in df: 188000, diff = 1000
#
#
# counter = 188 with 188000 documents elapsed
# Number of docs in df: 189000, diff = 1000
#
#
# counter = 189 with 189000 documents elapsed
# Number of docs in df: 190000, diff = 1000
#
#
# counter = 190 with 190000 documents elapsed
# Number of docs in df: 191000, diff = 1000
#
#
# counter = 191 with 191000 documents elapsed
# Number of docs in df: 192000, diff = 1000
#
#
# counter = 192 with 192000 documents elapsed
# Number of docs in df: 193000, diff = 1000
#
#
# counter = 193 with 193000 documents elapsed
# Number of docs in df: 194000, diff = 1000
#
#
# counter = 194 with 194000 documents elapsed
# Number of docs in df: 195000, diff = 1000
#
#
# counter = 195 with 195000 documents elapsed
# Number of docs in df: 196000, diff = 1000
#
#
# counter = 196 with 196000 documents elapsed
# Number of docs in df: 197000, diff = 1000
#
#
# counter = 197 with 197000 documents elapsed
# Number of docs in df: 198000, diff = 1000
#
#
# counter = 198 with 198000 documents elapsed
# Number of docs in df: 199000, diff = 1000
#
#
# counter = 199 with 199000 documents elapsed
# Number of docs in df: 200000, diff = 1000
#
#
# counter = 200 with 200000 documents elapsed
# Number of docs in df: 201000, diff = 1000
#
#
# counter = 201 with 201000 documents elapsed
# Number of docs in df: 202000, diff = 1000
#
#
# counter = 202 with 202000 documents elapsed
# Number of docs in df: 203000, diff = 1000
#
#
# counter = 203 with 203000 documents elapsed
# Number of docs in df: 204000, diff = 1000
#
#
# counter = 204 with 204000 documents elapsed
# Number of docs in df: 205000, diff = 1000
#
#
# counter = 205 with 205000 documents elapsed
# Number of docs in df: 206000, diff = 1000
#
#
# counter = 206 with 206000 documents elapsed
# Number of docs in df: 207000, diff = 1000
#
#
# counter = 207 with 207000 documents elapsed
# Number of docs in df: 208000, diff = 1000
#
#
# counter = 208 with 208000 documents elapsed
# Number of docs in df: 209000, diff = 1000
#
#
# counter = 209 with 209000 documents elapsed
# Number of docs in df: 210000, diff = 1000
#
#
# counter = 210 with 210000 documents elapsed
# Number of docs in df: 211000, diff = 1000
#
#
# counter = 211 with 211000 documents elapsed
# Number of docs in df: 212000, diff = 1000
#
#
# counter = 212 with 212000 documents elapsed
# Number of docs in df: 213000, diff = 1000
#
#
# counter = 213 with 213000 documents elapsed
# Number of docs in df: 214000, diff = 1000
#
#
# counter = 214 with 214000 documents elapsed
# Number of docs in df: 215000, diff = 1000
#
#
# counter = 215 with 215000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 215 with 215000 documents elapsed
# Number of docs in df: 216000, diff = 1000
#
#
# counter = 216 with 216000 documents elapsed
# Number of docs in df: 217000, diff = 1000
#
#
# counter = 217 with 217000 documents elapsed
# Number of docs in df: 218000, diff = 1000
#
#
# counter = 218 with 218000 documents elapsed
# Number of docs in df: 219000, diff = 1000
#
#
# counter = 219 with 219000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 219 with 219000 documents elapsed
# Number of docs in df: 220000, diff = 1000
#
#
# counter = 220 with 220000 documents elapsed
# Number of docs in df: 221000, diff = 1000
#
#
# counter = 221 with 221000 documents elapsed
# Number of docs in df: 222000, diff = 1000
#
#
# counter = 222 with 222000 documents elapsed
# Number of docs in df: 223000, diff = 1000
#
#
# counter = 223 with 223000 documents elapsed
# Number of docs in df: 224000, diff = 1000
#
#
# counter = 224 with 224000 documents elapsed
# Number of docs in df: 225000, diff = 1000
#
#
# counter = 225 with 225000 documents elapsed
# Number of docs in df: 226000, diff = 1000
#
#
# counter = 226 with 226000 documents elapsed
# Number of docs in df: 227000, diff = 1000
#
#
# counter = 227 with 227000 documents elapsed
# Number of docs in df: 228000, diff = 1000
#
#
# counter = 228 with 228000 documents elapsed
# Number of docs in df: 229000, diff = 1000
#
#
# counter = 229 with 229000 documents elapsed
# Number of docs in df: 230000, diff = 1000
#
#
# counter = 230 with 230000 documents elapsed
# Number of docs in df: 231000, diff = 1000
#
#
# counter = 231 with 231000 documents elapsed
# Number of docs in df: 232000, diff = 1000
#
#
# counter = 232 with 232000 documents elapsed
# Number of docs in df: 233000, diff = 1000
#
#
# counter = 233 with 233000 documents elapsed
# Number of docs in df: 234000, diff = 1000
#
#
# counter = 234 with 234000 documents elapsed
# Number of docs in df: 235000, diff = 1000
#
#
# counter = 235 with 235000 documents elapsed
# Number of docs in df: 236000, diff = 1000
#
#
# counter = 236 with 236000 documents elapsed
# Number of docs in df: 237000, diff = 1000
#
#
# counter = 237 with 237000 documents elapsed
# Number of docs in df: 238000, diff = 1000
#
#
# counter = 238 with 238000 documents elapsed
# Number of docs in df: 239000, diff = 1000
#
#
# counter = 239 with 239000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 239 with 239000 documents elapsed
# Number of docs in df: 240000, diff = 1000
#
#
# counter = 240 with 240000 documents elapsed
# Number of docs in df: 241000, diff = 1000
#
#
# counter = 241 with 241000 documents elapsed
# Number of docs in df: 242000, diff = 1000
#
#
# counter = 242 with 242000 documents elapsed
# Number of docs in df: 243000, diff = 1000
#
#
# counter = 243 with 243000 documents elapsed
# Number of docs in df: 244000, diff = 1000
#
#
# counter = 244 with 244000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 244 with 244000 documents elapsed
# Number of docs in df: 245000, diff = 1000
#
#
# counter = 245 with 245000 documents elapsed
# Number of docs in df: 246000, diff = 1000
#
#
# counter = 246 with 246000 documents elapsed
# Number of docs in df: 247000, diff = 1000
#
#
# counter = 247 with 247000 documents elapsed
# Number of docs in df: 248000, diff = 1000
#
#
# counter = 248 with 248000 documents elapsed
# Number of docs in df: 249000, diff = 1000
#
#
# counter = 249 with 249000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 249 with 249000 documents elapsed
# Number of docs in df: 250000, diff = 1000
#
#
# counter = 250 with 250000 documents elapsed
# Number of docs in df: 251000, diff = 1000
#
#
# counter = 251 with 251000 documents elapsed
# Number of docs in df: 252000, diff = 1000
#
#
# counter = 252 with 252000 documents elapsed
# Number of docs in df: 253000, diff = 1000
#
#
# counter = 253 with 253000 documents elapsed
# Number of docs in df: 254000, diff = 1000
#
#
# counter = 254 with 254000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 254 with 254000 documents elapsed
# Number of docs in df: 255000, diff = 1000
#
#
# counter = 255 with 255000 documents elapsed
# Number of docs in df: 256000, diff = 1000
#
#
# counter = 256 with 256000 documents elapsed
# Number of docs in df: 257000, diff = 1000
#
#
# counter = 257 with 257000 documents elapsed
# Number of docs in df: 258000, diff = 1000
#
#
# counter = 258 with 258000 documents elapsed
# Number of docs in df: 259000, diff = 1000
#
#
# counter = 259 with 259000 documents elapsed
# Number of docs in df: 260000, diff = 1000
#
#
# counter = 260 with 260000 documents elapsed
# Number of docs in df: 261000, diff = 1000
#
#
# counter = 261 with 261000 documents elapsed
# Number of docs in df: 262000, diff = 1000
#
#
# counter = 262 with 262000 documents elapsed
# Number of docs in df: 263000, diff = 1000
#
#
# counter = 263 with 263000 documents elapsed
# Number of docs in df: 264000, diff = 1000
#
#
# counter = 264 with 264000 documents elapsed
# Number of docs in df: 265000, diff = 1000
#
#
# counter = 265 with 265000 documents elapsed
# Number of docs in df: 266000, diff = 1000
#
#
# counter = 266 with 266000 documents elapsed
# Number of docs in df: 267000, diff = 1000
#
#
# counter = 267 with 267000 documents elapsed
# Number of docs in df: 268000, diff = 1000
#
#
# counter = 268 with 268000 documents elapsed
# Number of docs in df: 269000, diff = 1000
#
#
# counter = 269 with 269000 documents elapsed
# Number of docs in df: 270000, diff = 1000
#
#
# counter = 270 with 270000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 270 with 270000 documents elapsed
# Number of docs in df: 271000, diff = 1000
#
#
# counter = 271 with 271000 documents elapsed
# Number of docs in df: 272000, diff = 1000
#
#
# counter = 272 with 272000 documents elapsed
# Number of docs in df: 273000, diff = 1000
#
#
# counter = 273 with 273000 documents elapsed
# Number of docs in df: 274000, diff = 1000
#
#
# counter = 274 with 274000 documents elapsed
# Number of docs in df: 275000, diff = 1000
#
#
# counter = 275 with 275000 documents elapsed
# Number of docs in df: 276000, diff = 1000
#
#
# counter = 276 with 276000 documents elapsed
# Number of docs in df: 277000, diff = 1000
#
#
# counter = 277 with 277000 documents elapsed
# Number of docs in df: 278000, diff = 1000
#
#
# counter = 278 with 278000 documents elapsed
# Number of docs in df: 279000, diff = 1000
#
#
# counter = 279 with 279000 documents elapsed
# Number of docs in df: 280000, diff = 1000
#
#
# counter = 280 with 280000 documents elapsed
# Number of docs in df: 281000, diff = 1000
#
#
# counter = 281 with 281000 documents elapsed
# Number of docs in df: 282000, diff = 1000
#
#
# counter = 282 with 282000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 282 with 282000 documents elapsed
# Number of docs in df: 283000, diff = 1000
#
#
# counter = 283 with 283000 documents elapsed
# Number of docs in df: 284000, diff = 1000
#
#
# counter = 284 with 284000 documents elapsed
# Number of docs in df: 285000, diff = 1000
#
#
# counter = 285 with 285000 documents elapsed
# Number of docs in df: 286000, diff = 1000
#
#
# counter = 286 with 286000 documents elapsed
# Number of docs in df: 287000, diff = 1000
#
#
# counter = 287 with 287000 documents elapsed
# Number of docs in df: 288000, diff = 1000
#
#
# counter = 288 with 288000 documents elapsed
# Number of docs in df: 289000, diff = 1000
#
#
# counter = 289 with 289000 documents elapsed
# Number of docs in df: 290000, diff = 1000
#
#
# counter = 290 with 290000 documents elapsed
# Number of docs in df: 291000, diff = 1000
#
#
# counter = 291 with 291000 documents elapsed
# Number of docs in df: 292000, diff = 1000
#
#
# counter = 292 with 292000 documents elapsed
# Number of docs in df: 293000, diff = 1000
#
#
# counter = 293 with 293000 documents elapsed
# Number of docs in df: 294000, diff = 1000
#
#
# counter = 294 with 294000 documents elapsed
# Number of docs in df: 295000, diff = 1000
#
#
# counter = 295 with 295000 documents elapsed
# Number of docs in df: 296000, diff = 1000
#
#
# counter = 296 with 296000 documents elapsed
# Number of docs in df: 297000, diff = 1000
#
#
# counter = 297 with 297000 documents elapsed
# Number of docs in df: 298000, diff = 1000
#
#
# counter = 298 with 298000 documents elapsed
# Number of docs in df: 299000, diff = 1000
#
#
# counter = 299 with 299000 documents elapsed
# Number of docs in df: 300000, diff = 1000
#
#
# counter = 300 with 300000 documents elapsed
# Number of docs in df: 301000, diff = 1000
#
#
# counter = 301 with 301000 documents elapsed
# Number of docs in df: 302000, diff = 1000
#
#
# counter = 302 with 302000 documents elapsed
# Number of docs in df: 303000, diff = 1000
#
#
# counter = 303 with 303000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 303 with 303000 documents elapsed
# Number of docs in df: 304000, diff = 1000
#
#
# counter = 304 with 304000 documents elapsed
# Number of docs in df: 305000, diff = 1000
#
#
# counter = 305 with 305000 documents elapsed
# Number of docs in df: 306000, diff = 1000
#
#
# counter = 306 with 306000 documents elapsed
# Number of docs in df: 307000, diff = 1000
#
#
# counter = 307 with 307000 documents elapsed
# Number of docs in df: 308000, diff = 1000
#
#
# counter = 308 with 308000 documents elapsed
# Number of docs in df: 309000, diff = 1000
#
#
# counter = 309 with 309000 documents elapsed
# Number of docs in df: 310000, diff = 1000
#
#
# counter = 310 with 310000 documents elapsed
# Number of docs in df: 311000, diff = 1000
#
#
# counter = 311 with 311000 documents elapsed
# Number of docs in df: 312000, diff = 1000
#
#
# counter = 312 with 312000 documents elapsed
# Number of docs in df: 313000, diff = 1000
#
#
# counter = 313 with 313000 documents elapsed
# Number of docs in df: 314000, diff = 1000
#
#
# counter = 314 with 314000 documents elapsed
# Number of docs in df: 315000, diff = 1000
#
#
# counter = 315 with 315000 documents elapsed
# Number of docs in df: 316000, diff = 1000
#
#
# counter = 316 with 316000 documents elapsed
# Number of docs in df: 317000, diff = 1000
#
#
# counter = 317 with 317000 documents elapsed
# Number of docs in df: 318000, diff = 1000
#
#
# counter = 318 with 318000 documents elapsed
# Number of docs in df: 319000, diff = 1000
#
#
# counter = 319 with 319000 documents elapsed
# Number of docs in df: 320000, diff = 1000
#
#
# counter = 320 with 320000 documents elapsed
# Number of docs in df: 321000, diff = 1000
#
#
# counter = 321 with 321000 documents elapsed
# Number of docs in df: 322000, diff = 1000
#
#
# counter = 322 with 322000 documents elapsed
# Number of docs in df: 323000, diff = 1000
#
#
# counter = 323 with 323000 documents elapsed
# Number of docs in df: 324000, diff = 1000
#
#
# counter = 324 with 324000 documents elapsed
# Number of docs in df: 325000, diff = 1000
#
#
# counter = 325 with 325000 documents elapsed
# Number of docs in df: 326000, diff = 1000
#
#
# counter = 326 with 326000 documents elapsed
# Number of docs in df: 327000, diff = 1000
#
#
# counter = 327 with 327000 documents elapsed
# Number of docs in df: 328000, diff = 1000
#
#
# counter = 328 with 328000 documents elapsed
# Number of docs in df: 329000, diff = 1000
#
#
# counter = 329 with 329000 documents elapsed
# Number of docs in df: 330000, diff = 1000
#
#
# counter = 330 with 330000 documents elapsed
# Number of docs in df: 331000, diff = 1000
#
#
# counter = 331 with 331000 documents elapsed
# Number of docs in df: 332000, diff = 1000
#
#
# counter = 332 with 332000 documents elapsed
# Number of docs in df: 333000, diff = 1000
#
#
# counter = 333 with 333000 documents elapsed
# Number of docs in df: 334000, diff = 1000
#
#
# counter = 334 with 334000 documents elapsed
# Number of docs in df: 335000, diff = 1000
#
#
# counter = 335 with 335000 documents elapsed
# Number of docs in df: 336000, diff = 1000
#
#
# counter = 336 with 336000 documents elapsed
# Number of docs in df: 337000, diff = 1000
#
#
# counter = 337 with 337000 documents elapsed
# Number of docs in df: 338000, diff = 1000
#
#
# counter = 338 with 338000 documents elapsed
# Number of docs in df: 339000, diff = 1000
#
#
# counter = 339 with 339000 documents elapsed
# Number of docs in df: 340000, diff = 1000
#
#
# counter = 340 with 340000 documents elapsed
# Number of docs in df: 341000, diff = 1000
#
#
# counter = 341 with 341000 documents elapsed
# Number of docs in df: 342000, diff = 1000
#
#
# counter = 342 with 342000 documents elapsed
# Number of docs in df: 343000, diff = 1000
#
#
# counter = 343 with 343000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 343 with 343000 documents elapsed
# Number of docs in df: 344000, diff = 1000
#
#
# counter = 344 with 344000 documents elapsed
# Number of docs in df: 345000, diff = 1000
#
#
# counter = 345 with 345000 documents elapsed
# Number of docs in df: 346000, diff = 1000
#
#
# counter = 346 with 346000 documents elapsed
# Number of docs in df: 347000, diff = 1000
#
#
# counter = 347 with 347000 documents elapsed
# Number of docs in df: 348000, diff = 1000
#
#
# counter = 348 with 348000 documents elapsed
# Number of docs in df: 349000, diff = 1000
#
#
# counter = 349 with 349000 documents elapsed
# Number of docs in df: 350000, diff = 1000
#
#
# counter = 350 with 350000 documents elapsed
# Number of docs in df: 351000, diff = 1000
#
#
# counter = 351 with 351000 documents elapsed
# Number of docs in df: 352000, diff = 1000
#
#
# counter = 352 with 352000 documents elapsed
# Number of docs in df: 353000, diff = 1000
#
#
# counter = 353 with 353000 documents elapsed
# Number of docs in df: 354000, diff = 1000
#
#
# counter = 354 with 354000 documents elapsed
# Number of docs in df: 355000, diff = 1000
#
#
# counter = 355 with 355000 documents elapsed
# Number of docs in df: 356000, diff = 1000
#
#
# counter = 356 with 356000 documents elapsed
# Number of docs in df: 357000, diff = 1000
#
#
# counter = 357 with 357000 documents elapsed
# Number of docs in df: 358000, diff = 1000
#
#
# counter = 358 with 358000 documents elapsed
# Number of docs in df: 359000, diff = 1000
#
#
# counter = 359 with 359000 documents elapsed
# Number of docs in df: 360000, diff = 1000
#
#
# counter = 360 with 360000 documents elapsed
# Number of docs in df: 361000, diff = 1000
#
#
# counter = 361 with 361000 documents elapsed
# Number of docs in df: 362000, diff = 1000
#
#
# counter = 362 with 362000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 362 with 362000 documents elapsed
# Number of docs in df: 363000, diff = 1000
#
#
# counter = 363 with 363000 documents elapsed
# Number of docs in df: 364000, diff = 1000
#
#
# counter = 364 with 364000 documents elapsed
# Number of docs in df: 365000, diff = 1000
#
#
# counter = 365 with 365000 documents elapsed
# Number of docs in df: 366000, diff = 1000
#
#
# counter = 366 with 366000 documents elapsed
# Number of docs in df: 367000, diff = 1000
#
#
# counter = 367 with 367000 documents elapsed
# Number of docs in df: 368000, diff = 1000
#
#
# counter = 368 with 368000 documents elapsed
# Number of docs in df: 369000, diff = 1000
#
#
# counter = 369 with 369000 documents elapsed
# Number of docs in df: 370000, diff = 1000
#
#
# counter = 370 with 370000 documents elapsed
# Number of docs in df: 371000, diff = 1000
#
#
# counter = 371 with 371000 documents elapsed
# Number of docs in df: 372000, diff = 1000
#
#
# counter = 372 with 372000 documents elapsed
# Number of docs in df: 373000, diff = 1000
#
#
# counter = 373 with 373000 documents elapsed
# Number of docs in df: 374000, diff = 1000
#
#
# counter = 374 with 374000 documents elapsed
# Number of docs in df: 375000, diff = 1000
#
#
# counter = 375 with 375000 documents elapsed
# Number of docs in df: 376000, diff = 1000
#
#
# counter = 376 with 376000 documents elapsed
# Number of docs in df: 377000, diff = 1000
#
#
# counter = 377 with 377000 documents elapsed
# Number of docs in df: 378000, diff = 1000
#
#
# counter = 378 with 378000 documents elapsed
# Number of docs in df: 379000, diff = 1000
#
#
# counter = 379 with 379000 documents elapsed
# Number of docs in df: 380000, diff = 1000
#
#
# counter = 380 with 380000 documents elapsed
# Number of docs in df: 381000, diff = 1000
#
#
# counter = 381 with 381000 documents elapsed
# Number of docs in df: 382000, diff = 1000
#
#
# counter = 382 with 382000 documents elapsed
# Number of docs in df: 383000, diff = 1000
#
#
# counter = 383 with 383000 documents elapsed
# Number of docs in df: 384000, diff = 1000
#
#
# counter = 384 with 384000 documents elapsed
# Number of docs in df: 385000, diff = 1000
#
#
# counter = 385 with 385000 documents elapsed
# Number of docs in df: 386000, diff = 1000
#
#
# counter = 386 with 386000 documents elapsed
# Number of docs in df: 387000, diff = 1000
#
#
# counter = 387 with 387000 documents elapsed
# Number of docs in df: 388000, diff = 1000
#
#
# counter = 388 with 388000 documents elapsed
# Number of docs in df: 389000, diff = 1000
#
#
# counter = 389 with 389000 documents elapsed
# Number of docs in df: 390000, diff = 1000
#
#
# counter = 390 with 390000 documents elapsed
# Number of docs in df: 391000, diff = 1000
#
#
# counter = 391 with 391000 documents elapsed
# Number of docs in df: 392000, diff = 1000
#
#
# counter = 392 with 392000 documents elapsed
# Number of docs in df: 393000, diff = 1000
#
#
# counter = 393 with 393000 documents elapsed
# Number of docs in df: 394000, diff = 1000
#
#
# counter = 394 with 394000 documents elapsed
# Number of docs in df: 395000, diff = 1000
#
#
# counter = 395 with 395000 documents elapsed
# Number of docs in df: 396000, diff = 1000
#
#
# counter = 396 with 396000 documents elapsed
# Number of docs in df: 397000, diff = 1000
#
#
# counter = 397 with 397000 documents elapsed
# Number of docs in df: 398000, diff = 1000
#
#
# counter = 398 with 398000 documents elapsed
# Number of docs in df: 399000, diff = 1000
#
#
# counter = 399 with 399000 documents elapsed
# Number of docs in df: 400000, diff = 1000
#
#
# counter = 400 with 400000 documents elapsed
# Number of docs in df: 401000, diff = 1000
#
#
# counter = 401 with 401000 documents elapsed
# Number of docs in df: 402000, diff = 1000
#
#
# counter = 402 with 402000 documents elapsed
# Number of docs in df: 403000, diff = 1000
#
#
# counter = 403 with 403000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 403 with 403000 documents elapsed
# Number of docs in df: 404000, diff = 1000
#
#
# counter = 404 with 404000 documents elapsed
# Number of docs in df: 405000, diff = 1000
#
#
# counter = 405 with 405000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 405 with 405000 documents elapsed
# Number of docs in df: 406000, diff = 1000
#
#
# counter = 406 with 406000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 406 with 406000 documents elapsed
# Number of docs in df: 407000, diff = 1000
#
#
# counter = 407 with 407000 documents elapsed
# Number of docs in df: 408000, diff = 1000
#
#
# counter = 408 with 408000 documents elapsed
# Number of docs in df: 409000, diff = 1000
#
#
# counter = 409 with 409000 documents elapsed
# Number of docs in df: 410000, diff = 1000
#
#
# counter = 410 with 410000 documents elapsed
# Number of docs in df: 411000, diff = 1000
#
#
# counter = 411 with 411000 documents elapsed
# Number of docs in df: 412000, diff = 1000
#
#
# counter = 412 with 412000 documents elapsed
# Number of docs in df: 413000, diff = 1000
#
#
# counter = 413 with 413000 documents elapsed
# Number of docs in df: 414000, diff = 1000
#
#
# counter = 414 with 414000 documents elapsed
# Number of docs in df: 415000, diff = 1000
#
#
# counter = 415 with 415000 documents elapsed
# Number of docs in df: 416000, diff = 1000
#
#
# counter = 416 with 416000 documents elapsed
# Number of docs in df: 417000, diff = 1000
#
#
# counter = 417 with 417000 documents elapsed
# Number of docs in df: 418000, diff = 1000
#
#
# counter = 418 with 418000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 418 with 418000 documents elapsed
# Number of docs in df: 419000, diff = 1000
#
#
# counter = 419 with 419000 documents elapsed
# Number of docs in df: 420000, diff = 1000
#
#
# counter = 420 with 420000 documents elapsed
# Number of docs in df: 421000, diff = 1000
#
#
# counter = 421 with 421000 documents elapsed
# Number of docs in df: 422000, diff = 1000
#
#
# counter = 422 with 422000 documents elapsed
# Number of docs in df: 423000, diff = 1000
#
#
# counter = 423 with 423000 documents elapsed
# Number of docs in df: 424000, diff = 1000
#
#
# counter = 424 with 424000 documents elapsed
# Number of docs in df: 425000, diff = 1000
#
#
# counter = 425 with 425000 documents elapsed
# Number of docs in df: 426000, diff = 1000
#
#
# counter = 426 with 426000 documents elapsed
# Number of docs in df: 427000, diff = 1000
#
#
# counter = 427 with 427000 documents elapsed
# Number of docs in df: 428000, diff = 1000
#
#
# counter = 428 with 428000 documents elapsed
# Number of docs in df: 429000, diff = 1000
#
#
# counter = 429 with 429000 documents elapsed
# Number of docs in df: 430000, diff = 1000
#
#
# counter = 430 with 430000 documents elapsed
# Number of docs in df: 431000, diff = 1000
#
#
# counter = 431 with 431000 documents elapsed
# Number of docs in df: 432000, diff = 1000
#
#
# counter = 432 with 432000 documents elapsed
# Number of docs in df: 433000, diff = 1000
#
#
# counter = 433 with 433000 documents elapsed
# Number of docs in df: 434000, diff = 1000
#
#
# counter = 434 with 434000 documents elapsed
# Number of docs in df: 435000, diff = 1000
#
#
# counter = 435 with 435000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 435 with 435000 documents elapsed
# Number of docs in df: 436000, diff = 1000
#
#
# counter = 436 with 436000 documents elapsed
# Number of docs in df: 437000, diff = 1000
#
#
# counter = 437 with 437000 documents elapsed
# Number of docs in df: 438000, diff = 1000
#
#
# counter = 438 with 438000 documents elapsed
# Number of docs in df: 439000, diff = 1000
#
#
# counter = 439 with 439000 documents elapsed
# Error ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# counter = 439 with 439000 documents elapsed
# Number of docs in df: 440000, diff = 1000
#
#
# counter = 440 with 440000 documents elapsed
